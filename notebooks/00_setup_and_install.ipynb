# %% [markdown]
# # Phishing SMS : CoPhi @ SJTU
# **Author**: Napassorn LITCHIOWONG (Pleng/林艺文)
# pleng@u.nus.edu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# REPO_DIR="/content/drive/MyDrive/sms-baselines"
# if [ ! -d "$REPO_DIR" ]; then git clone https://www.github.com/iamdiluxedbutcooler/sms-baselines.git "$REPO_DIR"; fi
# cd "$REPO_DIR"
# git status --porcelain > /tmp/git_changes.txt
# if [ -s /tmp/git_changes.txt ]; then ts=$(date +%Y%m%dT%H%M%S); cd ..; tar -czf sms-baselines-backup-$ts.tar.gz sms-baselines; cd sms-baselines; fi
# branch=$(git rev-parse --abbrev-ref HEAD || echo "main")
# git fetch origin --prune
# git reset --hard origin/$branch
# git clean -fdx
# git pull
# git status
# Out:
# HEAD is now at 234bc6e Merge branch 'main' of https://github.com/iamdiluxedbutcooler/sms-baselines
# Removing experiments/aggregated_summary_by_baseline.csv
# Removing experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/classification_report_table.csv
# Removing experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/confusion_matrix.png
# Removing experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/detailed_error_analysis.png
# Removing experiments/comprehensive_baseline_analysis.png
# Removing experiments/confusion_matrices_all_baselines.png
# Removing experiments/detailed_metrics_comparison.png
# Removing experiments/experiment_summary.json
# Removing experiments/metrics_summary_table.csv
# On branch main
# nothing to commit, working tree clean
# tar: sms-baselines/.git/description: file changed as we read it
# tar: sms-baselines/.git/hooks/push-to-checkout.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/prepare-commit-msg.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/pre-applypatch.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/commit-msg.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/pre-rebase.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/pre-receive.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/applypatch-msg.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/pre-push.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/pre-commit.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/fsmonitor-watchman.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/update.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/pre-merge-commit.sample: file changed as we read it
# tar: sms-baselines/.git/hooks/post-update.sample: file changed as we read it
# tar: sms-baselines/.git/info/exclude: file changed as we read it
# tar: sms-baselines/.git/refs/heads/main: file changed as we read it
# tar: sms-baselines/.git/refs/remotes/origin/main: file changed as we read it
# tar: sms-baselines/.git/refs/remotes/origin: file changed as we read it
# tar: sms-baselines/.git/objects/pack/pack-2b0393b19597376566c460b449702d5a5b55ed80.pack: file changed as we read it
# tar: sms-baselines/.git/objects/pack/pack-2b0393b19597376566c460b449702d5a5b55ed80.idx: file changed as we read it
# tar: sms-baselines/.git/objects/6d/c974eb09cabbfed5c526684f306facee93a2cc: file changed as we read it
# tar: sms-baselines/.git/objects/8f/3f583d82314295131c9484e5d50227f21bba70: file changed as we read it
# tar: sms-baselines/.git/objects/75/679bfe39034f87fb0042555f5d2112fe7fa9c8: file changed as we read it
# tar: sms-baselines/.git/objects/00/b472102f65ff1c7d9e8eecc4e74be5ef77298a: file changed as we read it
# tar: sms-baselines/.git/objects/00/8da04844bcfd6771584bdbd1dadfa9e32d75f1: file changed as we read it
# tar: sms-baselines/.git/objects/18/495a98284debe6894ae36ccbba89bc6d679699: file changed as we read it
# tar: sms-baselines/.git/objects/18/4f64ee3aeab8973d0e6f626204a4e31db26ddb: file changed as we read it
# tar: sms-baselines/.git/objects/59/7be0eede27b05340b937556faf5c36890db6b4: file changed as we read it
# tar: sms-baselines/.git/objects/59/15453b675fef17e634a96ac874dd8d052e78b1: file changed as we read it
# tar: sms-baselines/.git/objects/35/2dc1e17da559f10189277ae688221b46f5e597: file changed as we read it
# tar: sms-baselines/.git/objects/35/29b9bea89b247888da277045826c0af5eb17c9: file changed as we read it
# tar: sms-baselines/.git/objects/a8/8fe613da899c9924a6b86a53a29ef71d05aa33: file changed as we read it
# tar: sms-baselines/.git/objects/f4/231784b97c5b39cb7e3d0b36b2eeea9a6b5113: file changed as we read it
# tar: sms-baselines/.git/objects/ce/1811a7a172724933d619853f4e8376d444ce16: file changed as we read it
# tar: sms-baselines/.git/objects/2c/6f14d5b210565f5c2298d4e1700dd15bb3badd: file changed as we read it
# tar: sms-baselines/.git/objects/a0/2ba3015dd1a94cec9bcf1a759682b27b2b79a3: file changed as we read it
# tar: sms-baselines/.git/objects/dd/1d3f20454bd656251c8fe25523c4a05789910f: file changed as we read it
# tar: sms-baselines/.git/objects/f1/875761cf9eed1bd6a8d6101ae117eb1336c364: file changed as we read it
# tar: sms-baselines/.git/objects/45/d9188e60b37415c3572086d6cb21c00c78015a: file changed as we read it
# tar: sms-baselines/.git/objects/77/5a30324b6bbcfef35085abc5b6327748d5fd1d: file changed as we read it
# tar: sms-baselines/.git/objects/fa/b24aed736656f02be8c43bd9254f4805cd54c4: file changed as we read it
# tar: sms-baselines/.git/objects/57/3e44d9ead753801f919f657a79c0374f669e2f: file changed as we read it
# tar: sms-baselines/.git/objects/c5/e2ea11f5e29967fb96d3de031b1322b0c799cb: file changed as we read it
# tar: sms-baselines/.git/objects/e6/0f5924da5e8c616305db3330d92501c5894fc5: file changed as we read it
# tar: sms-baselines/.git/objects/d4/36183b4b0697a07358855ff64073f6d621edab: file changed as we read it
# tar: sms-baselines/.git/objects/d4/0d682919612c47e635d4c46151d02dc9ac25bf: file changed as we read it
# tar: sms-baselines/.git/objects/85/0bd2c6bfae2e99dd73c4a83df01e35f85e97ec: file changed as we read it
# tar: sms-baselines/.git/objects/85/2ee9c869811c841ee9b7a6ed5f8c5aa9c1051f: file changed as we read it
# tar: sms-baselines/.git/objects/82/021c3612f2f9502778b971913c56d28f3a4539: file changed as we read it
# tar: sms-baselines/.git/objects/f0/0e403988f2daecae74ce0aabed4fd4d4aa135d: file changed as we read it
# tar: sms-baselines/.git/objects/a3/6019b3c90ef1da792ae3ceba8dfef708ec0985: file changed as we read it
# tar: sms-baselines/.git/objects/a3/db71c43e792ab634284064b0a0ef694d727aac: file changed as we read it
# tar: sms-baselines/.git/objects/d3/f1c29d0eec5d8ff30c15da5395e5098dc8884e: file changed as we read it
# tar: sms-baselines/.git/objects/60/6008b2f649c5e88c8ab460759a00f3e5b3b5aa: file changed as we read it
# tar: sms-baselines/.git/objects/51/8aff1b66104c578df9503d1eea519be5cd6138: file changed as we read it
# tar: sms-baselines/.git/objects/98/631718abc314365af7252deaf07ec161dc08b9: file changed as we read it
# tar: sms-baselines/.git/objects/98/ebb8c1ce0f99971dbb7a33184200fc22c57f79: file changed as we read it
# tar: sms-baselines/.git/objects/8e/b17a57d73b56017d4de882b5460f7fc00a755f: file changed as we read it
# tar: sms-baselines/.git/objects/dc/5281b2066e82cbe6fc7bb7c59f4d33d0db0b81: file changed as we read it
# tar: sms-baselines/.git/objects/dc: file changed as we read it
# tar: sms-baselines/.git/objects/6c/0008eb8b20721702c5118772cbf4129a47cb49: file changed as we read it
# tar: sms-baselines/.git/objects/8d/443b7b2ad2d8590a6270728d42eaa2602dd4a5: file changed as we read it
# tar: sms-baselines/.git/objects/bf/5b652e568e3cd499d87b185a4e1975cbfe5ed6: file changed as we read it
# tar: sms-baselines/.git/objects/71/41c9e3d6884e21360f61c30341a4f2aaa2bb73: file changed as we read it
# tar: sms-baselines/.git/objects/71/55b44fa063a41da45226846e50448de7ce0184: file changed as we read it
# tar: sms-baselines/.git/objects/db/fa77d9a0cf40a43465f226dbe57208381476ec: file changed as we read it
# tar: sms-baselines/.git/objects/93/1efc3704d7daab59512038942dc7496541be47: file changed as we read it
# tar: sms-baselines/.git/objects/a7/9e432577e31135ceed0c4851adfc9b687523d0: file changed as we read it
# tar: sms-baselines/.git/objects/6a/793a200fcc6a282a8b8f86a539e94c98060387: file changed as we read it
# tar: sms-baselines/.git/objects/90/fea7385ff97ab61e08aaa1137ff687f28113b3: file changed as we read it
# tar: sms-baselines/.git/objects/5a/dbad71801f2947474591a0d95dc0d812219ced: file changed as we read it
# tar: sms-baselines/.git/objects/2f/2bde0f3c5a79faa6605a3088d79635cdbbca21: file changed as we read it
# tar: sms-baselines/.git/objects/1d/02caf5ed55057564d4eecc81799025ab5411f2: file changed as we read it
# tar: sms-baselines/.git/objects/d0/4570ed425200e5828a863b040975525b9a8512: file changed as we read it
# tar: sms-baselines/.git/objects/de/409968d16b3dd5980727b6e27d6e3a81e2eed0: file changed as we read it
# tar: sms-baselines/.git/objects/7f/c6d230e260696a7b5d501178c4776a01092d67: file changed as we read it
# tar: sms-baselines/.git/objects/88/6d2ced190d60cf8f357515819f7d43e7bb443d: file changed as we read it
# tar: sms-baselines/.git/objects/cf/1914a1cb8ab02b7aebc65926b2ed9c645cd2c3: file changed as we read it
# tar: sms-baselines/.git/objects/cf/9084981b95d002e31e6fdcc1491ab26bfeebe4: file changed as we read it
# tar: sms-baselines/.git/objects/03/31c7d52711a3e86ca6ef0cdc45f9ded62e85a7: file changed as we read it
# tar: sms-baselines/.git/objects/b3/e136597edca546a0a09d2e68d250db364152a2: file changed as we read it
# tar: sms-baselines/.git/objects/df/b6257e0eb70659f05449a450b82aaa364cafc1: file changed as we read it
# tar: sms-baselines/.git/objects/bb/385c179fbde31ada432bbfb9c5284f463967c1: file changed as we read it
# tar: sms-baselines/.git/objects/1c/861b6ee2c2c159964d3d256fbab505209e974a: file changed as we read it
# tar: sms-baselines/.git/objects/91/e4a7314384149bea82981e22c8523a7866432a: file changed as we read it
# tar: sms-baselines/.git/objects/39/5ea3c528147c580d2c9b28a0ac4cf390d9055d: file changed as we read it
# tar: sms-baselines/.git/objects/c2/f1e03e28ea003045e059cdce167074a797c021: file changed as we read it
# tar: sms-baselines/.git/objects/41/c21913f6889c974c07eb7c96793ab164efb262: file changed as we read it
# tar: sms-baselines/.git/objects/08/a4eb7920533f12e34086da62ff13cfc1233741: file changed as we read it
# tar: sms-baselines/.git/objects/89/8b70f364316b8c23041073f4635bf1ff1fa122: file changed as we read it
# tar: sms-baselines/.git/objects/f2/10a4a7a2da0599c2b0180a9fcf5a2e7b1e3e19: file changed as we read it
# tar: sms-baselines/.git/objects/65/2b8c8855b47f9ba92ac1c29126782a20c9c63c: file changed as we read it
# tar: sms-baselines/.git/packed-refs: file changed as we read it
# tar: sms-baselines/.git/logs/refs/remotes/origin/main: file changed as we read it
# tar: sms-baselines/.git/logs/refs/remotes/origin: file changed as we read it
# tar: sms-baselines/.git/logs/refs/heads/main: file changed as we read it
# tar: sms-baselines/.git/logs/HEAD: file changed as we read it
# tar: sms-baselines/.git/HEAD: file changed as we read it
# tar: sms-baselines/.git/config: file changed as we read it
# tar: sms-baselines/.git/index: file changed as we read it
# tar: sms-baselines/.git/FETCH_HEAD: file changed as we read it
# tar: sms-baselines/.git/ORIG_HEAD: file changed as we read it
# tar: sms-baselines/.git/COMMIT_EDITMSG: file changed as we read it
# tar: sms-baselines/README.md: file changed as we read it
# tar: sms-baselines/configs/bl_nlp_01.yaml: file changed as we read it
# tar: sms-baselines/configs/bl_nlp_02.yaml: file changed as we read it
# tar: sms-baselines/data/raw/mendeley.csv: file changed as we read it
# tar: sms-baselines/data/splits/splits_manifest.json: file changed as we read it
# tar: sms-baselines/data/splits/test.csv: file changed as we read it
# tar: sms-baselines/data/splits/train.csv: file changed as we read it
# tar: sms-baselines/src/models/nlp/BL_NLP_01_mishra2020.py: file changed as we read it
# tar: sms-baselines/src/models/nlp/BL_NLP_02_salman2024.py: file changed as we read it
# tar: sms-baselines/src/models/shared.py: file changed as we read it
# tar: sms-baselines/experiments/experiments_summary.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/summary.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed46_20250922T212037Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed46_20250922T212037Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed46_20250922T212037Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed46_20250922T212037Z/fallback_logreg.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed45_20250922T212035Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed45_20250922T212035Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed45_20250922T212035Z/fallback_logreg.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed45_20250922T212035Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed44_20250922T212034Z/fallback_logreg.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed44_20250922T212034Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed44_20250922T212034Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed44_20250922T212034Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed43_20250922T212032Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed43_20250922T212032Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed43_20250922T212032Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed43_20250922T212032Z/fallback_logreg.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/fallback_logreg.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/detailed_error_analysis.png: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/confusion_matrix.png: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_02/bl_nlp_02_seed42_20250922T212031Z/classification_report_table.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/summary.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed46_20250922T212029Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed46_20250922T212029Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed46_20250922T212029Z/model.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed46_20250922T212029Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed45_20250922T212027Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed45_20250922T212027Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed45_20250922T212027Z/model.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed45_20250922T212027Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed44_20250922T212025Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed44_20250922T212025Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed44_20250922T212025Z/model.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed44_20250922T212025Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed43_20250922T212024Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed43_20250922T212024Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed43_20250922T212024Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed43_20250922T212024Z/model.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed42_20250922T212021Z/results_detailed.csv: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed42_20250922T212021Z/results.json: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed42_20250922T212021Z/model.joblib: file changed as we read it
# tar: sms-baselines/experiments/bl_nlp_01/bl_nlp_01_seed42_20250922T212021Z/run_meta.json: file changed as we read it
# tar: sms-baselines/experiments/comprehensive_baseline_analysis.png: file changed as we read it
# tar: sms-baselines/experiments/detailed_metrics_comparison.png: file changed as we read it
# tar: sms-baselines/experiments/experiment_summary.json: file changed as we read it
# tar: sms-baselines/experiments/aggregated_summary_by_baseline.csv: file changed as we read it
# tar: sms-baselines/experiments/metrics_summary_table.csv: file changed as we read it
# tar: sms-baselines/experiments/confusion_matrices_all_baselines.png: file changed as we read it
# From https://github.com/iamdiluxedbutcooler/sms-baselines
#    08a4eb7..234bc6e  main       -> origin/main
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> main
