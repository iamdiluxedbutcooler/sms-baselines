# %% [markdown]
# # Phishing SMS : CoPhi @ SJTU
# **Author**: Napassorn LITCHIOWONG (Pleng/林艺文)
# pleng@u.nus.edu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# REPO_DIR="/content/drive/MyDrive/sms-baselines"
# if [ ! -d "$REPO_DIR" ]; then git clone https://www.github.com/iamdiluxedbutcooler/sms-baselines.git "$REPO_DIR"; fi
# cd "$REPO_DIR"
# git status --porcelain > /tmp/git_changes.txt
# if [ -s /tmp/git_changes.txt ]; then ts=$(date +%Y%m%dT%H%M%S); cd ..; tar -czf sms-baselines-backup-$ts.tar.gz sms-baselines; cd sms-baselines; fi
# branch=$(git rev-parse --abbrev-ref HEAD || echo "main")
# git fetch origin --prune
# git reset --hard origin/$branch
# git clean -fdx
# git pull
# git status
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     210         try:
# --> 211             out, err = p.communicate(cell)
#     212         except KeyboardInterrupt:
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     414         try:
# ...
